# %% [markdown]
# <a href="https://colab.research.google.com/github/Yang12350/1st-PyCrawlerMarathon/blob/master/%E5%B7%A8%E9%87%8F%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90(%E7%B5%82).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re  #把標點符號都去掉
delimiter = "，|。|、"  
text = '''《科學報告》《scientific reports》的期刊中，有研究報告指出環境溫度對攻擊性行為之間的生物性關聯機制。探討了環境溫度，血清素轉運密度與暴力犯罪發生之間關係的關係。

人體調節暴力行為的關鍵-血清素系統

科學研究指出，在生物體中，血清素系統在調節暴力行為中起了主要作用，暴力犯罪者中的血清素系統受季節性變化的影響比健康受試者大，溫度上升會調節血清素的傳遞功能，增加衝動性及煩躁感和人們的活動性，導致社會交往和暴力事件風險增加。

氣溫和犯罪率的關係

研究團隊為了要調查氣溫和犯罪率之間的關係，對月份進行個別統計並提出3個研究方向：

1.環境溫度會影響犯罪率或血清素系統
2.血清素系統和犯罪率之間的關係
3.除去太陽輻射的季節性變化外，是否存在一個共同因素去影響環境溫度，血清素系統和暴力犯罪率？

結果顯示，高環境溫度和日照會影響暴力犯罪者大腦的血清素活性，增加暴力犯罪的發生。研究團隊也調查了1996 ~2013年期間芬蘭殺人事件的季節性變化，顯示當溫度每增加1.7％時，芬蘭的暴力犯罪率增加了10%的變化。

並證明，環境溫度對暴力犯罪發生的影響，部分是透過血清素系統調整的，平均氣溫上升2°C時，尤其是超過28°C後，非暴力犯罪區域的暴力犯罪率增加3%。

此外，當氣溫上升時，人們會更多地出去見面，這會增加暴力事件的發生率。因此，暴力犯罪率的上升也歸因於受害者的血清素活化，而不只是犯罪者的血清素被活化。所以，若您交往的對象在天氣熱時，火氣會比較大的話，避免見面或許是另一種自保的方法。

'''
for i in re.split(delimiter, text):
    print (i)
# Out:
# 《科學報告》《scientific reports》的期刊中
# 有研究報告指出環境溫度對攻擊性行為之間的生物性關聯機制
# 探討了環境溫度
# 血清素轉運密度與暴力犯罪發生之間關係的關係
#
#
# 人體調節暴力行為的關鍵-血清素系統
#
# 科學研究指出
# 在生物體中
# 血清素系統在調節暴力行為中起了主要作用
# 暴力犯罪者中的血清素系統受季節性變化的影響比健康受試者大
# 溫度上升會調節血清素的傳遞功能
# 增加衝動性及煩躁感和人們的活動性
# 導致社會交往和暴力事件風險增加
#
#
# 氣溫和犯罪率的關係
#
# 研究團隊為了要調查氣溫和犯罪率之間的關係
# 對月份進行個別統計並提出3個研究方向：
#
# 1.環境溫度會影響犯罪率或血清素系統
# 2.血清素系統和犯罪率之間的關係
# 3.除去太陽輻射的季節性變化外
# 是否存在一個共同因素去影響環境溫度
# 血清素系統和暴力犯罪率？
#
# 結果顯示
# 高環境溫度和日照會影響暴力犯罪者大腦的血清素活性
# 增加暴力犯罪的發生
# 研究團隊也調查了1996 ~2013年期間芬蘭殺人事件的季節性變化
# 顯示當溫度每增加1.7％時
# 芬蘭的暴力犯罪率增加了10%的變化
#
#
# 並證明
# 環境溫度對暴力犯罪發生的影響
# 部分是透過血清素系統調整的
# 平均氣溫上升2°C時
# 尤其是超過28°C後
# 非暴力犯罪區域的暴力犯罪率增加3%
#
#
# 此外
# 當氣溫上升時
# 人們會更多地出去見面
# 這會增加暴力事件的發生率
# 因此
# 暴力犯罪率的上升也歸因於受害者的血清素活化
# 而不只是犯罪者的血清素被活化
# 所以
# 若您交往的對象在天氣熱時
# 火氣會比較大的話
# 避免見面或許是另一種自保的方法

# %%
# !pip install -q wordcloud
# !pip install -q jieba

# %%
# !wget https://raw.githubusercontent.com/victorgau/wordcloud/master/dict.txt.big -o /dev/null
# !wget https://raw.githubusercontent.com/victorgau/wordcloud/master/SourceHanSansTW-Regular.otf -o /dev/null

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba

# %%
jieba.set_dictionary('dict.txt.big')
wordlist = jieba.cut(text)
words = " ".join(wordlist)

# 從 Google 下載的中文字型
font = 'SourceHanSansTW-Regular.otf'
my_wordcloud = WordCloud(font_path=font).generate(words)

plt.imshow(my_wordcloud)
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from /content/dict.txt.big ...
# DEBUG:jieba:Building prefix dict from /content/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# Loading model cost 1.269 seconds.
# DEBUG:jieba:Loading model cost 1.269 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Out:
# --2020-07-02 08:55:52--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [text/plain]
# Saving to: ‘dict.txt.big.1’
#
# dict.txt.big.1      100%[===================>]   8.18M  18.2MB/s    in 0.5s
#
# 2020-07-02 08:55:53 (18.2 MB/s) - ‘dict.txt.big.1’ saved [8583143/8583143]

# %%
# !head dict.txt.big
# Out:
# 1号店 3 n
# 1號店 3 n
# 4S店 3 n
# 4s店 3 n
# AA制 3 n
# AB型 3 n
# AT&T 3 nz
# A型 3 n
# A座 3 n
# A股 3 n

# %%
import re
delimiter = "，|。|、"  
text1 = '''
侯副市長在近四十年的警察背景下，觀察到犯罪率和氣候的一定關係。從數據很明顯可以看出，在夏天時，因為悶熱的天氣，衝突性的暴力犯罪案例跟溫度一樣直線上升，甚至性犯罪案件也增多，這與人在炎熱氣候下情緒不穩定有絕對關係。相對的，冬天氣溫下降，類似的事件就減少，但宵小犯罪率明顯上升，所以這時警方就會加強警力，在人煙稀少的街道、死角處多巡邏。

 

除了以上，侯副市長也提到，在台灣梅雨季節，自殺率顯著提升，這也和持續的陰雨天，影響人們心理有所關。

侯肯定的表示，氣候與人類的犯罪行為，是截然相關的，儘管不是一對一的因果關係，但在資料紀錄上，可以看出一定的趨勢。天氣條件潛在影響著犯罪者的心理，間接影響其判斷行為、或是成為犯罪的誘因。

在接下新北市副市長這位置後，侯也將一樣的概念力行到治理新北市上，尤其新北市在對寒害、熱浪方面有很好的應變機制，可以看到侯對氣候的重視。

 

「觀察氣候，準備工作」。

副市長認為，比起事後的省思，在事前的預防更加實際，所以在幅員廣大、各種天然災害皆有的新北市，侯與天氣風險公司合作，用專業和效率兼具的預測，讓新北市在面對各種氣候變化時，在最快的時間點做最佳的預防或處理，大量的減少各種傷亡。

最後，侯副市長強調，政府會不斷精進、檢討天氣對人民造成的傷害度、加強預防，也期許大家配合政府的公告與措施，因為只有在雙方的相互信任與合作下，才能將傷亡降到最低。
'''
for i in re.split(delimiter, text1):
    print (i)
# Out:
# 侯副市長在近四十年的警察背景下
# 觀察到犯罪率和氣候的一定關係
# 從數據很明顯可以看出
# 在夏天時
# 因為悶熱的天氣
# 衝突性的暴力犯罪案例跟溫度一樣直線上升
# 甚至性犯罪案件也增多
# 這與人在炎熱氣候下情緒不穩定有絕對關係
# 相對的
# 冬天氣溫下降
# 類似的事件就減少
# 但宵小犯罪率明顯上升
# 所以這時警方就會加強警力
# 在人煙稀少的街道
# 死角處多巡邏
#
#
#
#
# 除了以上
# 侯副市長也提到
# 在台灣梅雨季節
# 自殺率顯著提升
# 這也和持續的陰雨天
# 影響人們心理有所關
#
#
# 侯肯定的表示
# 氣候與人類的犯罪行為
# 是截然相關的
# 儘管不是一對一的因果關係
# 但在資料紀錄上
# 可以看出一定的趨勢
# 天氣條件潛在影響著犯罪者的心理
# 間接影響其判斷行為
# 或是成為犯罪的誘因
#
#
# 在接下新北市副市長這位置後
# 侯也將一樣的概念力行到治理新北市上
# 尤其新北市在對寒害
# 熱浪方面有很好的應變機制
# 可以看到侯對氣候的重視
#
#
#
#
# 「觀察氣候
# 準備工作」
#
#
# 副市長認為
# 比起事後的省思
# 在事前的預防更加實際
# 所以在幅員廣大
# 各種天然災害皆有的新北市
# 侯與天氣風險公司合作
# 用專業和效率兼具的預測
# 讓新北市在面對各種氣候變化時
# 在最快的時間點做最佳的預防或處理
# 大量的減少各種傷亡
#
#
# 最後
# 侯副市長強調
# 政府會不斷精進
# 檢討天氣對人民造成的傷害度
# 加強預防
# 也期許大家配合政府的公告與措施
# 因為只有在雙方的相互信任與合作下
# 才能將傷亡降到最低

# %%
jieba.set_dictionary('dict.txt.big')
wordlist = jieba.cut(text1)
words = " ".join(wordlist)

# 從 Google 下載的中文字型
font = 'SourceHanSansTW-Regular.otf'
my_wordcloud = WordCloud(font_path=font).generate(words)

plt.imshow(my_wordcloud)
plt.axis("off")
plt.show()
# Out:
# Building prefix dict from /content/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# Loading model cost 1.272 seconds.
# Prefix dict has been built successfully.

# %%
def ngram(input_sentence, n = 2):
    ret = []
    for i in range(0, len(input_sentence) - n + 1):
        ret.append(input_sentence[i:i+n])
    return ret

# %%
ngram(text1, 3)
# Out:
# ['\n侯副',
#  '侯副市',
#  '副市長',
#  '市長在',
#  '長在近',
#  '在近四',
#  '近四十',
#  '四十年',
#  '十年的',
#  '年的警',
#  '的警察',
#  '警察背',
#  '察背景',
#  '背景下',
#  '景下，',
#  '下，觀',
#  '，觀察',
#  '觀察到',
#  '察到犯',
#  '到犯罪',
#  '犯罪率',
#  '罪率和',
#  '率和氣',
#  '和氣候',
#  '氣候的',
#  '候的一',
#  '的一定',
#  '一定關',
#  '定關係',
#  '關係。',
#  '係。從',
#  '。從數',
#  '從數據',
#  '數據很',
#  '據很明',
#  '很明顯',
#  '明顯可',
#  '顯可以',
#  '可以看',
#  '以看出',
#  '看出，',
#  '出，在',
#  '，在夏',
#  '在夏天',
#  '夏天時',
#  '天時，',
#  '時，因',
#  '，因為',
#  '因為悶',
#  '為悶熱',
#  '悶熱的',
#  '熱的天',
#  '的天氣',
#  '天氣，',
#  '氣，衝',
#  '，衝突',
#  '衝突性',
#  '突性的',
#  '性的暴',
#  '的暴力',
#  '暴力犯',
#  '力犯罪',
#  '犯罪案',
#  '罪案例',
#  '案例跟',
#  '例跟溫',
#  '跟溫度',
#  '溫度一',
#  '度一樣',
#  '一樣直',
#  '樣直線',
#  '直線上',
#  '線上升',
#  '上升，',
#  '升，甚',
#  '，甚至',
#  '甚至性',
#  '至性犯',
#  '性犯罪',
#  '犯罪案',
#  '罪案件',
#  '案件也',
#  '件也增',
#  '也增多',
#  '增多，',
#  '多，這',
#  '，這與',
#  '這與人',
#  '與人在',
#  '人在炎',
#  '在炎熱',
#  '炎熱氣',
#  '熱氣候',
#  '氣候下',
#  '候下情',
#  '下情緒',
#  '情緒不',
#  '緒不穩',
#  '不穩定',
# ...

# %%
dic = {}
for w in text1:
    if w not in dic:
        dic[w] = 1
    else:
        dic[w] = dic[w] + 1

# %%
import operator
swd = sorted(dic.items(), key = operator.itemgetter(1), reverse=True)
swd[1:10]
# Out:
# [('的', 28),
#  ('\n', 18),
#  ('在', 14),
#  ('氣', 11),
#  ('市', 10),
#  ('。', 10),
#  ('天', 8),
#  ('侯', 7),
#  ('犯', 7)]

# %%
from collections import Counter
words = ngram(text1,2)
c = Counter(words)
c.most_common(5)
# Out:
# [('\n\n', 8), ('犯罪', 7), ('。\n', 7), ('氣候', 6), ('副市', 5)]

# %%
import re
sentenceAry = re.split('，|。|（|）|〕|〔|／|《|》|、|」|！|「|：',text1)

# %%
def removeKey(text, keywords):
    ret = text
    for word in keywords:
        ret = ret.replace(word, '')
    return ret

removeKey(text1, ['侯', '核准', '期貨'])
# Out:
# '\n副市長在近四十年的警察背景下，觀察到犯罪率和氣候的一定關係。從數據很明顯可以看出，在夏天時，因為悶熱的天氣，衝突性的暴力犯罪案例跟溫度一樣直線上升，甚至性犯罪案件也增多，這與人在炎熱氣候下情緒不穩定有絕對關係。相對的，冬天氣溫下降，類似的事件就減少，但宵小犯罪率明顯上升，所以這時警方就會加強警力，在人煙稀少的街道、死角處多巡邏。\n\n \n\n除了以上，副市長也提到，在台灣梅雨季節，自殺率顯著提升，這也和持續的陰雨天，影響人們心理有所關。\n\n肯定的表示，氣候與人類的犯罪行為，是截然相關的，儘管不是一對一的因果關係，但在資料紀錄上，可以看出一定的趨勢。天氣條件潛在影響著犯罪者的心理，間接影響其判斷行為、或是成為犯罪的誘因。\n\n在接下新北市副市長這位置後，也將一樣的概念力行到治理新北市上，尤其新北市在對寒害、熱浪方面有很好的應變機制，可以看到對氣候的重視。\n\n \n\n「觀察氣候，準備工作」。\n\n副市長認為，比起事後的省思，在事前的預防更加實際，所以在幅員廣大、各種天然災害皆有的新北市，與天氣風險公司合作，用專業和效率兼具的預測，讓新北市在面對各種氣候變化時，在最快的時間點做最佳的預防或處理，大量的減少各種傷亡。\n\n最後，副市長強調，政府會不斷精進、檢討天氣對人民造成的傷害度、加強預防，也期許大家配合政府的公告與措施，因為只有在雙方的相互信任與合作下，才能將傷亡降到最低。\n'

# %%
keywords = []

for n in range(4,1,-1):
    #print(n)
    words = []
    for sentence in sentenceAry:
        text_list = removeKey(sentence, keywords)
        words.extend(ngram(text_list, n))
    c = Counter(words)
    for word, cnt in c.items():
        if cnt >= 4:
            keywords.append(word)
keywords
# Out:
# ['副市長', '新北市', '犯罪', '氣候', '天氣', '\n\n']

# %%
def longTermFirst(news, keywords, threshold):
    sentenceAry = re.split('，|。|（|）|〕|〔|／|《|》|、|」|！|「|：',news)

    for n in range(4,1,-1):
        words = []
        for sentence in sentenceAry:
            text_list = removeKey(sentence, keywords)
            words.extend(ngram(text_list, n))
            
        c = Counter(words)
        for word, cnt in c.items():
            m = re.match('^[\u4e00-\u9fa5]+$', word)
            if (cnt >= threshold) and m:
                keywords.append(word)
    return keywords

# %%
longTermFirst(text1, [],3)
# Out:
# ['侯副市長', '可以看', '新北市', '犯罪', '氣候', '關係', '天氣', '影響', '的預', '預防', '各種']

# %%
from collections import Counter
words = list(jieba.cut(text1))
c = Counter(words)
for k,v in c.most_common(50):
    if len(k) > 1:
        print(k,v)
# Out:
# 新北市 5
# 氣候 4
# 天氣 4
# 侯副市 3
# 可以 3
# 影響 3
# 預防 3
# 各種 3
# 犯罪率 2
# 一定 2
# 明顯 2
# 看出 2
# 因為 2
# 上升 2
# 減少 2
# 所以 2
# 加強 2
# 心理 2
# 犯罪 2
# 行為 2
# 市長 2
# 合作 2
# 政府 2
# 四十年 1
# 警察 1
# 背景 1
# 觀察到 1

# %%
import re  #把標點符號都去掉
delimiter = "，|。|、" 
text2='''
世界越來越熱，人的脾氣也越大嗎？最新大型科學研究報告顯示，氣溫上升的確可能提高人類暴力犯罪及戰爭的機率。

該研究2013年8月刊登在《科學》（Science）權威期刊。主要研究者加州大學柏克萊分校經濟學者索羅門‧謝恩(Solomon Hsiang)指出，研究結果證實：「當氣候越熱，人們就越有可能出現攻擊他人的行為。」

謝恩為了驗證氣溫與衝突行為的關聯，翻閱幾十起帝國的崩落歷史、15起犯罪與侵犯行為紀錄，以及30起戰爭、民族內戰。

謝恩指出，實驗室溫度越高，警察越容易扣下板機。另一項研究指出，棒球投手在炎熱的天氣看到隊友被對手的球擊中身體，越可能採取報復行為。馬雅文明的衰落，時間點正巧也落在1,200年前的大乾旱。

共同作者、柏克萊經濟學者愛德華‧米奎爾(Edward Miguel)表示，其他研究也有類似結論。若氣候變遷的態勢不變，21世紀中葉全球氣溫可能會再攀升華氏3.6度(華氏1度=攝氏5/9度)，非洲發生戰爭的風險可能增加40%至50%。

這群經濟學家的研究歸納出一項公式，用來預測極端氣候可能引發暴力事件的風險機率。根據這個公式，位處熱帶、戰亂頻仍的非洲，平均每上升華氏1度，就有11%到14%的機率發生叛亂與內戰。美國平均溫度每上升華氏5.4度，暴力犯罪風險會飆升2%到4%。

刊登於當期《科學》的另一篇分析研究也指出，根據目前暖化的速度，北美與歐亞大陸氣溫將在西元2065年前再增加5.4度。
 
新聞中的環境科學知識

俄亥俄州立大學心理學教授布萊德‧布希曼(Brad Bushman)專門研究氣溫與犯罪的關係，他提出不同解讀，認為或許人類的衝動行為會與炎熱的天氣有關係，但天氣越熱同樣可能使人發懶。進一步檢測這些人的心跳與生理反應，確實會因為高溫而導致刺激，但不能夠證明高溫跟衝動的情緒與行為有直接的因果關係。

美國大學國際關係教授約書亞‧高斯坦(Joshua Goldstein)認為，即便溫度越高越可能脾氣壞，但這也只是釀成衝突行為的因素之一而已。

'''
for i in re.split(delimiter, text2):
    print (i)
# Out:
# 世界越來越熱
# 人的脾氣也越大嗎？最新大型科學研究報告顯示
# 氣溫上升的確可能提高人類暴力犯罪及戰爭的機率
#
#
# 該研究2013年8月刊登在《科學》（Science）權威期刊
# 主要研究者加州大學柏克萊分校經濟學者索羅門‧謝恩(Solomon Hsiang)指出
# 研究結果證實：「當氣候越熱
# 人們就越有可能出現攻擊他人的行為
# 」
#
# 謝恩為了驗證氣溫與衝突行為的關聯
# 翻閱幾十起帝國的崩落歷史
# 15起犯罪與侵犯行為紀錄
# 以及30起戰爭
# 民族內戰
#
#
# 謝恩指出
# 實驗室溫度越高
# 警察越容易扣下板機
# 另一項研究指出
# 棒球投手在炎熱的天氣看到隊友被對手的球擊中身體
# 越可能採取報復行為
# 馬雅文明的衰落
# 時間點正巧也落在1,200年前的大乾旱
#
#
# 共同作者
# 柏克萊經濟學者愛德華‧米奎爾(Edward Miguel)表示
# 其他研究也有類似結論
# 若氣候變遷的態勢不變
# 21世紀中葉全球氣溫可能會再攀升華氏3.6度(華氏1度=攝氏5/9度)
# 非洲發生戰爭的風險可能增加40%至50%
#
#
# 這群經濟學家的研究歸納出一項公式
# 用來預測極端氣候可能引發暴力事件的風險機率
# 根據這個公式
# 位處熱帶
# 戰亂頻仍的非洲
# 平均每上升華氏1度
# 就有11%到14%的機率發生叛亂與內戰
# 美國平均溫度每上升華氏5.4度
# 暴力犯罪風險會飆升2%到4%
#
#
# 刊登於當期《科學》的另一篇分析研究也指出
# 根據目前暖化的速度
# 北美與歐亞大陸氣溫將在西元2065年前再增加5.4度
#
#
# 新聞中的環境科學知識
#
# 俄亥俄州立大學心理學教授布萊德‧布希曼(Brad Bushman)專門研究氣溫與犯罪的關係
# 他提出不同解讀
# 認為或許人類的衝動行為會與炎熱的天氣有關係
# 但天氣越熱同樣可能使人發懶
# 進一步檢測這些人的心跳與生理反應
# 確實會因為高溫而導致刺激
# 但不能夠證明高溫跟衝動的情緒與行為有直接的因果關係
#
#
# 美國大學國際關係教授約書亞‧高斯坦(Joshua Goldstein)認為
# 即便溫度越高越可能脾氣壞
# 但這也只是釀成衝突行為的因素之一而已

# %%
from collections import Counter
words = ngram(text2,2)
c = Counter(words)
c.most_common(5)
# Out:
# [('研究', 9), ('\n\n', 9), ('可能', 8), ('。\n', 8), ('行為', 7)]

# %%
def longTermFirst(news, keywords, threshold):
    sentenceAry = re.split('，|。|（|）|〕|〔|／|《|》|、|」|！|「|：',news)

    for n in range(4,1,-1):
        words = []
        for sentence in sentenceAry:
            text_list = removeKey(sentence, keywords)
            words.extend(ngram(text_list, n))
            
        c = Counter(words)
        for word, cnt in c.items():
            m = re.match('^[\u4e00-\u9fa5]+$', word)
            if (cnt >= threshold) and m:
                keywords.append(word)
    return keywords

# %%
longTermFirst(text2, [],3)
# Out:
# ['經濟學',
#  '升華氏',
#  '越熱',
#  '人的',
#  '科學',
#  '研究',
#  '氣溫',
#  '可能',
#  '暴力',
#  '犯罪',
#  '戰爭',
#  '機率',
#  '大學',
#  '謝恩',
#  '指出',
#  '氣候',
#  '行為',
#  '溫度',
#  '天氣',
#  '風險',
#  '關係']

# %%
from collections import Counter
words = list(jieba.cut(text2))
c = Counter(words)
for k,v in c.most_common(50):
    if len(k) > 1:
        print(k,v)
# Out:
# 可能 8
# 研究 7
# 行為 7
# 氣溫 5
# 指出 4
# 華氏 4
# 上升 3
# 戰爭 3
# 機率 3
# 謝恩 3
# 天氣 3
# 風險 3
# 關係 3
# 人類 2
# 暴力犯罪 2
# 刊登 2
# 科學 2
# 柏克萊 2
# 經濟 2
# 學者 2
# 氣候 2
# 越熱 2
# 衝突 2
# 犯罪 2
# 內戰 2
# 溫度 2

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
model = hub.load(module_url) #download and load the model

doc = ["哪些因子決定地球的氣候",
       "氣候變化與天氣之間有何關係",
       "人類活動如何引起氣候變化及其他自然影響相比如何",
       "地球的溫度正在發生怎樣的變化",
       "熱浪、乾旱、洪水和颶風等極端事件是否發生了變化",
       "地球上的冰雪量是否正在減少",
       "與地球歷史上的早期變化相比，當前的氣候變化異常嗎", 
       "用來預估未來氣候變化的模式可靠性如何",
       "海平面在上升嗎",
       "能夠預估不同區堿的氣候變化嗎"]
print("Total number of text samples: ",len(doc))
doc
# Out:
# Total number of text samples:  10
# ['哪些因子決定地球的氣候',
#  '氣候變化與天氣之間有何關係',
#  '人類活動如何引起氣候變化及其他自然影響相比如何',
#  '地球的溫度正在發生怎樣的變化',
#  '熱浪、乾旱、洪水和颶風等極端事件是否發生了變化',
#  '地球上的冰雪量是否正在減少',
#  '與地球歷史上的早期變化相比，當前的氣候變化異常嗎',
#  '用來預估未來氣候變化的模式可靠性如何',
#  '海平面在上升嗎',
#  '能夠預估不同區堿的氣候變化嗎']

# %%
 import matplotlib.pyplot as plt
 import matplotlib as mpl
 zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/liberation/simhei.ttf')
 plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
bank_vec = model(doc)
print(bank_vec.shape)
# Out:
# (10, 512)

# %%
import seaborn as sns #關於氣候與情緒的問答
# !wget -O /usr/share/fonts/truetype/liberation/simhei.ttf "https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf" #加這行
zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/liberation/simhei.ttf') #加這行
query = ["溫度的改變會影響心理嗎?"]
query_vec = model(query) #encodes the string in the list
correlation = np.transpose(np.inner(query_vec,bank_vec))
sns.set(font_scale=1.2)



sns.set(font=zhfont.get_name())

plt.xticks(fontproperties=zhfont)#加這行
plt.yticks(fontproperties=zhfont)#加這行

g = sns.heatmap(
      correlation,
      xticklabels=query,
      yticklabels=doc,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
print("Closest match found to '",query[0],"' is '",doc[np.argmax(correlation, axis=0)[0]],"'")
print('correlation: \n', correlation)
# Out:
# --2020-07-02 16:57:25--  https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10050870 (9.6M) [application/octetstream]
# Saving to: ‘/usr/share/fonts/truetype/liberation/simhei.ttf’
#
# /usr/share/fonts/tr 100%[===================>]   9.58M  5.41MB/s    in 1.8s
#
# 2020-07-02 16:57:28 (5.41 MB/s) - ‘/usr/share/fonts/truetype/liberation/simhei.ttf’ saved [10050870/10050870]
# WARNING:matplotlib.font_manager:findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.
# Closest match found to ' 溫度的改變會影響心理嗎? ' is ' 氣候變化與天氣之間有何關係 '
# correlation:
#  [[0.50008595]
#  [0.55968726]
#  [0.2626681 ]
#  [0.3760615 ]
#  [0.5194195 ]
#  [0.45282036]
#  [0.50759745]
#  [0.44591314]
#  [0.37234187]
#  [0.36567587]]

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"  
#"https://tfhub.dev/google/universal-sentence-encoder-large/5"
model = hub.load(module_url)
print ("module %s loaded" % module_url)
def embed(input):
  return model(input)
# Out:
# module https://tfhub.dev/google/universal-sentence-encoder/4 loaded

# %%
# !wget -O /usr/share/fonts/truetype/liberation/simhei.ttf "https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf" #加這行
zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/liberation/simhei.ttf') #加這行
plt.xticks(fontproperties=zhfont)#加這行
plt.yticks(fontproperties=zhfont)#加這行

def plot_similarity(labels, features, rotation):
  corr = np.inner(features, features)
  #plt.figure(figsize=(10,6), dpi=300)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation)
  g.set_title("Semantic Textual Similarity")

def run_and_plot(messages_):
  message_embeddings_ = embed(messages_)
  plot_similarity(messages_, message_embeddings_, 90)

messages = [
   "哪些因子決定地球的氣候",
       "氣候變化與天氣之間有何關係",
       "人類活動如何引起氣候變化及其他自然影響相比如何",
       "地球的溫度正在發生怎樣的變化",
       "熱浪、乾旱、洪水和颶風等極端事件是否發生了變化",
       "地球上的冰雪量是否正在減少",
       "與地球歷史上的早期變化相比，當前的氣候變化異常嗎", 
       "用來預估未來氣候變化的模式可靠性如何",
       "海平面在上升嗎",
       "能夠預估不同區堿的氣候變化嗎"
]

#run_and_plot(messages)
message_embeddings = embed(messages)
plot_similarity(messages, message_embeddings, 90)
# Out:
# --2020-07-02 15:46:20--  https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10050870 (9.6M) [application/octetstream]
# Saving to: ‘/usr/share/fonts/truetype/liberation/simhei.ttf’
#
# /usr/share/fonts/tr 100%[===================>]   9.58M  2.93MB/s    in 3.6s
#
# 2020-07-02 15:46:24 (2.69 MB/s) - ‘/usr/share/fonts/truetype/liberation/simhei.ttf’ saved [10050870/10050870]

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import seaborn as sns

module_url = "https://tfhub.dev/google/universal-sentence-encoder/4" 
model = hub.load(module_url) #download and load the model

doc1 = ["天氣濕冷會讓人心情好差嗎",
       "什麼影響了心情",
       "什麼是季節性情緒失調",
       "激發情緒波動的原因有哪些",
       "情緒會影響行為嗎",
       "憤怒的心情還有和那些因素有關",
       "觸覺會影響心情嗎"]
print("Total number of text samples: ",len(doc1))
doc1
# Out:
# Total number of text samples:  7
# ['天氣濕冷會讓人心情好差嗎',
#  '什麼影響了心情',
#  '什麼是季節性情緒失調',
#  '激發情緒波動的原因有哪些',
#  '情緒會影響行為嗎',
#  '憤怒的心情還有和那些因素有關',
#  '觸覺會影響心情嗎']

# %%
bank_vec = model(doc1)
print(bank_vec.shape)
# Out:
# (7, 512)

# %%
import seaborn as sns #關於氣候與情緒的問答
# !wget -O /usr/share/fonts/truetype/liberation/simhei.ttf "https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf" #加這行
zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/liberation/simhei.ttf') #加這行
query = ["溫度的改變會影響心理嗎?"]
query_vec = model(query) #encodes the string in the list
correlation = np.transpose(np.inner(query_vec,bank_vec))
sns.set(font_scale=1.2)



sns.set(font=zhfont.get_name())

plt.xticks(fontproperties=zhfont)#加這行
plt.yticks(fontproperties=zhfont)#加這行

g = sns.heatmap(
      correlation,
      xticklabels=query,
      yticklabels=doc1,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
print("Closest match found to '",query[0],"' is '",doc1[np.argmax(correlation, axis=0)[0]],"'")
print('correlation: \n', correlation)
# Out:
# --2020-07-02 17:19:59--  https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10050870 (9.6M) [application/octetstream]
# Saving to: ‘/usr/share/fonts/truetype/liberation/simhei.ttf’
#
# /usr/share/fonts/tr 100%[===================>]   9.58M  4.92MB/s    in 1.9s
#
# 2020-07-02 17:20:01 (4.92 MB/s) - ‘/usr/share/fonts/truetype/liberation/simhei.ttf’ saved [10050870/10050870]
#
# Closest match found to ' 溫度的改變會影響心理嗎? ' is ' 什麼是季節性情緒失調 '
# correlation:
#  [[0.51878285]
#  [0.5208979 ]
#  [0.5777829 ]
#  [0.44615188]
#  [0.5217589 ]
#  [0.48941392]
#  [0.45574728]]

# %%
# !wget -O /usr/share/fonts/truetype/liberation/simhei.ttf "https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf" #加這行
zhfont = mpl.font_manager.FontProperties(fname='/usr/share/fonts/truetype/liberation/simhei.ttf') #加這行
plt.xticks(fontproperties=zhfont)#加這行
plt.yticks(fontproperties=zhfont)#加這行

def plot_similarity(labels, features, rotation):
  corr = np.inner(features, features)
  #plt.figure(figsize=(10,6), dpi=300)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation)
  g.set_title("Semantic Textual Similarity")

def run_and_plot(messages_):
  message_embeddings_ = embed(messages_)
  plot_similarity(messages_, message_embeddings_, 90)

messages = [
  "天氣濕冷會讓人心情好差嗎",
       "什麼影響了心情",
       "什麼是季節性情緒失調",
       "激發情緒波動的原因有哪些",
       "情緒會影響行為嗎",
       "憤怒的心情還有和那些因素有關",
       "觸覺會影響心情嗎"
]

#run_and_plot(messages)
message_embeddings = embed(messages)
plot_similarity(messages, message_embeddings, 90)
# Out:
# --2020-07-02 17:21:41--  https://www.wfonts.com/download/data/2014/06/01/simhei/chinese.simhei.ttf
# Resolving www.wfonts.com (www.wfonts.com)... 104.225.219.210
# Connecting to www.wfonts.com (www.wfonts.com)|104.225.219.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10050870 (9.6M) [application/octetstream]
# Saving to: ‘/usr/share/fonts/truetype/liberation/simhei.ttf’
#
# /usr/share/fonts/tr 100%[===================>]   9.58M  2.41MB/s    in 4.5s
#
# 2020-07-02 17:21:47 (2.13 MB/s) - ‘/usr/share/fonts/truetype/liberation/simhei.ttf’ saved [10050870/10050870]
# WARNING:matplotlib.font_manager:findfont: Font family ['SimHei'] not found. Falling back to DejaVu Sans.
